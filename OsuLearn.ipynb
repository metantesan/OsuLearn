# %% [markdown]
# # OsuLearn
# ## An attempt at creating a Neural Network that learns how to play osu!std like a human from replays
#
# ##### (Plz don't judge me too much I'm new to machine learning and I can't english)

# %%
import os
import re
import math
import glob
from importlib import reload

import tensorflow as tf
import tensorflow.python.keras as keras
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

import osu.rulesets.beatmap
import osu.rulesets.replay
import osu.rulesets.hitobjects as hitobjects
import osulearn.dataset
# Out:
# 2024-02-09 18:13:14.087655: E external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:9261] Unable to register cuDNN factory: Attempting to register factory for plugin cuDNN when one has already been registered
# 2024-02-09 18:13:14.087690: E external/local_xla/xla/stream_executor/cuda/cuda_fft.cc:607] Unable to register cuFFT factory: Attempting to register factory for plugin cuFFT when one has already been registered
# 2024-02-09 18:13:14.104970: E external/local_xla/xla/stream_executor/cuda/cuda_blas.cc:1515] Unable to register cuBLAS factory: Attempting to register factory for plugin cuBLAS when one has already been registered
# 2024-02-09 18:13:14.133235: I tensorflow/core/platform/cpu_feature_guard.cc:182] This TensorFlow binary is optimized to use available CPU instructions in performance-critical operations.
# To enable the following instructions: SSE3 SSE4.1 SSE4.2 AVX AVX2 AVX_VNNI FMA, in other operations, rebuild TensorFlow with the appropriate compiler flags.

# %%
OSU_FOLDER = "/mnt/c/Users/Omen/AppData/Local/osu!"
#os.path.join(os.getenv('LocalAppData'), "osu!")

# %% [markdown]
# ## Objective
#
# This project aims to create a Neural Network that is capable of learning how to play osu! as humanly as possible.
#
#
# ## Approach
#
# To accomplish that, I'll be applying [supervised learning](https://en.wikipedia.org/wiki/Supervised_learning) by feeding a [Recurrent Neural Network](https://en.wikipedia.org/wiki/Recurrent_neural_network) with beatmap data as input, training it to reproduce replay data from my recorded plays. These will be read from my Replay and Songs directories at my osu! installation respectively.
#
# In the future, it would be interesting to try and implement a Conditional [Generative Adversarial Network (GAN)](https://en.wikipedia.org/wiki/Generative_adversarial_network) model that receives beatmap data as input and outputs replay data, as this would allow to generate a variety of replays for the same map, which the current model can't do.
#
# ## The learning data
#
# First, all the `.osr` files in the osu! directory are enumerated and put into a table mapping replay file names to the `.osu` file for the replay's beatmap.
#
# This is quite expensive to do every time, so a cache file is stored in the `.data/` folder in OsuLearn root dir to reduce overhead. Also, the code is huge and not very enlightening (it's basically a bunch of `glob`s), so it's been moved to `osulearn/dataset.py` to avoid cluttering this notebook.

# %%
if not os.path.exists('.data'):
    os.makedirs('.data')
data_files = osulearn.dataset.all_files(OSU_FOLDER, verbose=True)


    
#data_files.applymap(os.path.basename)
# Out:
# [=======================================>] /mnt/c/Users/Omen/AppData/Local/...

# %% [markdown]
# After enumerating the required files, they are mapped into `osu.ruleset` objects so we can extract useful information from them. This is done separately from file enumeration mainly because I like to see the Replay/Beatmap filename table, and it's nice to have a progress bar for each step.
#
# Please notice DT and HR are not supported because they change timing and object position respectively, and I'm too lazy atm to take that into account.

# %%
dataset = osulearn.dataset.load(data_files, verbose=2)
# Out:
# [=======================================>] metantesan - ZAQ - Sparkling Day...

# %% [markdown]
# With our `osu.ruleset` objects DataFrame in hands, we can now get the data we are really interested in. This step is very time consuming, mainly because it has to calculate the list of visible objects for each frame on every beatmap. I've applyed some optimizations on that but it's still quite time-consuming.
#
# The generated input and target data are stored on files in the `.data/` folder in OsuLearn root dir, and are not updated if the generated files are present. If you have saved a new replay, please delete `.data/input_data.dat` and `.data/target_data.dat`.

# %%
try:
    input_data = pd.read_pickle('.data/input_data.dat')
except:
    input_data = osulearn.dataset.input_data(dataset, verbose=True)
    input_data.to_pickle('.data/input_data.dat')

X = np.reshape(input_data.values, (-1, osulearn.dataset.BATCH_LENGTH, len(osulearn.dataset.INPUT_FEATURES)))

X.shape
# Out:
# [=======================================>] Sparkling Daydream (TV Size)
# (14, 2048, 5)

# %%
try:
    target_data = pd.read_pickle('.data/target_data.dat')
except:
    target_data = osulearn.dataset.target_data(dataset, verbose=True)
    target_data.to_pickle('.data/target_data.dat')

y = np.reshape(target_data.values, (-1, osulearn.dataset.BATCH_LENGTH, len(osulearn.dataset.OUTPUT_FEATURES)))

y.shape
# Out:
# [=======================================>] Sparkling Daydream (TV Size)
# (14, 2048, 2)

# %% [markdown]
# ## Neural Network model
#
# The training data is ready, so the next step is to create our model. As I've said at the beginning, I'm new to Machine Learning, so this model is built mostly on top of educated guesses.
#
# I think it's reasonable to use a LSTM because replays are time sequences and it's past states are relevant to calculate the next one. Maybe I should use some kind of convolutional layer, but I'm not sure where and how and when I tried to it just made the cursor shake like hell, so maybe not.

# %%
from tensorflow.keras.models import Model
from tensorflow.keras.layers import Dense, Input, GaussianNoise
from tensorflow.compat.v1.keras.layers import CuDNNLSTM as LSTM
map_input = Input(shape=X.shape[1:], name='map_info')

lstm = LSTM(64, return_sequences=True)(map_input)
pos = Dense(64, activation='linear')(lstm)
pos = GaussianNoise(0.2)(pos)
pos = Dense(16, activation='linear')(pos)
pos = Dense(y.shape[2], activation='linear', name='position')(pos)

model = Model(inputs=map_input, outputs=pos)
model.compile(optimizer="adam", loss='mae')
model.summary()

try:
    model.load_weights(".data/model.hdf5")
except Exception as e:
    print()
    print("Failed to load weights: ", e)
# Out:
# 2024-02-09 18:13:39.365557: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-02-09 18:13:39.468547: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-02-09 18:13:39.468585: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-02-09 18:13:39.472470: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-02-09 18:13:39.472499: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-02-09 18:13:39.472511: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-02-09 18:13:39.579635: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-02-09 18:13:39.579954: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-02-09 18:13:39.579969: I tensorflow/core/common_runtime/gpu/gpu_device.cc:2022] Could not identify NUMA node of platform GPU id 0, defaulting to 0.  Your kernel may not have been built with NUMA support.
# 2024-02-09 18:13:39.579995: I external/local_xla/xla/stream_executor/cuda/cuda_executor.cc:887] could not open file to read NUMA node: /sys/bus/pci/devices/0000:01:00.0/numa_node
# Your kernel may have been built without NUMA support.
# 2024-02-09 18:13:39.580010: I tensorflow/core/common_runtime/gpu/gpu_device.cc:1929] Created device /job:localhost/replica:0/task:0/device:GPU:0 with 9502 MB memory:  -> device: 0, name: NVIDIA GeForce RTX 4070 Ti, pci bus id: 0000:01:00.0, compute capability: 8.9
# 2024-02-09 18:13:39.580646: I tensorflow/core/common_runtime/process_util.cc:146] Creating new thread pool with default inter op setting: 2. Tune using inter_op_parallelism_threads for best performance.
# Model: "model"
# _________________________________________________________________
#  Layer (type)                Output Shape              Param #
# =================================================================
#  map_info (InputLayer)       [(None, 2048, 5)]         0
#
#  cu_dnnlstm (CuDNNLSTM)      (None, 2048, 64)          18176
#
#  dense (Dense)               (None, 2048, 64)          4160
#
#  gaussian_noise (GaussianNoi  (None, 2048, 64)         0
#  se)
#
#  dense_1 (Dense)             (None, 2048, 16)          1040
#
#  position (Dense)            (None, 2048, 2)           34
#
# =================================================================
# Total params: 23,410
# Trainable params: 23,410
# Non-trainable params: 0
# _________________________________________________________________
#
# Failed to load weights:  [Errno 2] Unable to synchronously open file (unable to open file: name = '.data/model.hdf5', errno = 2, error message = 'No such file or directory', flags = 0, o_flags = 0)

# %% [markdown]
# ## Training
#
# The training is done by splitting the dataset randomly into training and testing groups and exposing the Neural Network only to the training group. This process is then repeated until the loss is acceptable.
#
# From my experience, a good point to stop is at about 0.0600. The number of epochs until this happens may vary depending on the size of the dataset, so feel free to tweak the `ITERATIONS` and `EPOCHS` values as needed to approach this result (or run the next cell until it's done, whatever).

# %%
from random import randint
from sklearn.model_selection import train_test_split

ITERATIONS = 24
EPOCHS = 8

try:
    loss
except NameError:
    loss = []
    
for i in range(ITERATIONS):
    print("Iteration #%d" % (i + 1))
    print("_" * 80)
    print()
    X_train, X_test, y_train, y_test = train_test_split(X, y, test_size=0.3, random_state=randint(0, 100))
    h = model.fit(X_train, y_train, batch_size=1024, epochs=EPOCHS, verbose=1)
    loss += h.history['loss']
    print()

model.save_weights(".data/model.hdf5")
# Out:
# Iteration #1
# ________________________________________________________________________________
#
# Epoch 1/8
# 2024-02-09 18:13:49.175251: I external/local_xla/xla/stream_executor/cuda/cuda_dnn.cc:454] Loaded cuDNN version 8907
# 2024-02-09 18:13:49.743722: I external/local_xla/xla/service/service.cc:168] XLA service 0x7fc565dfe730 initialized for platform CUDA (this does not guarantee that XLA will be used). Devices:
# 2024-02-09 18:13:49.743750: I external/local_xla/xla/service/service.cc:176]   StreamExecutor device (0): NVIDIA GeForce RTX 4070 Ti, Compute Capability 8.9
# 2024-02-09 18:13:49.758451: I tensorflow/compiler/mlir/tensorflow/utils/dump_mlir_util.cc:269] disabling MLIR crash reproducer, set env var `MLIR_CRASH_REPRODUCER_DIRECTORY` to enable.
# WARNING: All log messages before absl::InitializeLog() is called are written to STDERR
# I0000 00:00:1707489829.859796     273 device_compiler.h:186] Compiled cluster using XLA!  This line is logged at most once for the lifetime of the process.
# 1/1 [==============================] - 2s 2s/step - loss: 0.3600
# Epoch 2/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3513
# Epoch 3/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3380
# Epoch 4/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3285
# Epoch 5/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.3194
# Epoch 6/8
# 1/1 [==============================] - 0s 33ms/step - loss: 0.3109
# Epoch 7/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.3021
# Epoch 8/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2968
#
# Iteration #2
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2913
# Epoch 2/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2851
# Epoch 3/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2786
# Epoch 4/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2728
# Epoch 5/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2692
# Epoch 6/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2634
# Epoch 7/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2604
# Epoch 8/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2563
#
# Iteration #3
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2531
# Epoch 2/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2495
# Epoch 3/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2481
# Epoch 4/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2421
# Epoch 5/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2383
# Epoch 6/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2332
# Epoch 7/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2321
# Epoch 8/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2275
#
# Iteration #4
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2218
# Epoch 2/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2185
# Epoch 3/8
# 1/1 [==============================] - 0s 33ms/step - loss: 0.2178
# Epoch 4/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2133
# Epoch 5/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.2091
# Epoch 6/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.2062
# Epoch 7/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.2023
# Epoch 8/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1998
#
# Iteration #5
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1940
# Epoch 2/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1922
# Epoch 3/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1884
# Epoch 4/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1843
# Epoch 5/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1810
# Epoch 6/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1788
# Epoch 7/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1759
# Epoch 8/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1728
#
# Iteration #6
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1742
# Epoch 2/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1714
# Epoch 3/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1672
# Epoch 4/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1645
# Epoch 5/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1617
# Epoch 6/8
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1584
# Epoch 7/8
# 1/1 [==============================] - 0s 33ms/step - loss: 0.1565
# Epoch 8/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1554
#
# Iteration #7
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1507
# Epoch 2/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1485
# Epoch 3/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1445
# Epoch 4/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1433
# Epoch 5/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1405
# Epoch 6/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1381
# Epoch 7/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1360
# Epoch 8/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1345
#
# Iteration #8
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1313
# Epoch 2/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.1305
# Epoch 3/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1287
# Epoch 4/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1260
# Epoch 5/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1247
# Epoch 6/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1225
# Epoch 7/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1209
# Epoch 8/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1185
#
# Iteration #9
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 40ms/step - loss: 0.1159
# Epoch 2/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1144
# Epoch 3/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1131
# Epoch 4/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1114
# Epoch 5/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1097
# Epoch 6/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1078
# Epoch 7/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1064
# Epoch 8/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1051
#
# Iteration #10
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1072
# Epoch 2/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1055
# Epoch 3/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1045
# Epoch 4/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1036
# Epoch 5/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.1021
# Epoch 6/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.1000
# Epoch 7/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0991
# Epoch 8/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0971
#
# Iteration #11
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0954
# Epoch 2/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0938
# Epoch 3/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0924
# Epoch 4/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0918
# Epoch 5/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0904
# Epoch 6/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0892
# Epoch 7/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0883
# Epoch 8/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0883
#
# Iteration #12
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0888
# Epoch 2/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0878
# Epoch 3/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0870
# Epoch 4/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0864
# Epoch 5/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0851
# Epoch 6/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0844
# Epoch 7/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0848
# Epoch 8/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0835
#
# Iteration #13
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0777
# Epoch 2/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0769
# Epoch 3/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0765
# Epoch 4/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0760
# Epoch 5/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0749
# Epoch 6/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0746
# Epoch 7/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0739
# Epoch 8/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0736
#
# Iteration #14
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0774
# Epoch 2/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0768
# Epoch 3/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0759
# Epoch 4/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0756
# Epoch 5/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0750
# Epoch 6/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0743
# Epoch 7/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0748
# Epoch 8/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0734
#
# Iteration #15
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 37ms/step - loss: 0.0720
# Epoch 2/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0727
# Epoch 3/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0723
# Epoch 4/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0718
# Epoch 5/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0710
# Epoch 6/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0711
# Epoch 7/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0705
# Epoch 8/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0709
#
# Iteration #16
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0714
# Epoch 2/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0715
# Epoch 3/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0711
# Epoch 4/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0701
# Epoch 5/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0709
# Epoch 6/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0699
# Epoch 7/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0699
# Epoch 8/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0694
#
# Iteration #17
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0673
# Epoch 2/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0676
# Epoch 3/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0676
# Epoch 4/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0672
# Epoch 5/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0669
# Epoch 6/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0662
# Epoch 7/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0666
# Epoch 8/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0660
#
# Iteration #18
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0635
# Epoch 2/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0637
# Epoch 3/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0637
# Epoch 4/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0628
# Epoch 5/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0627
# Epoch 6/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0629
# Epoch 7/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0620
# Epoch 8/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0622
#
# Iteration #19
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0657
# Epoch 2/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0652
# Epoch 3/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0653
# Epoch 4/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0647
# Epoch 5/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0645
# Epoch 6/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0647
# Epoch 7/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0640
# Epoch 8/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0642
#
# Iteration #20
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0647
# Epoch 2/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0642
# Epoch 3/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0646
# Epoch 4/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0639
# Epoch 5/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0636
# Epoch 6/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0640
# Epoch 7/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0632
# Epoch 8/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0633
#
# Iteration #21
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0601
# Epoch 2/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0600
# Epoch 3/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0596
# Epoch 4/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0593
# Epoch 5/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0594
# Epoch 6/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0592
# Epoch 7/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0589
# Epoch 8/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0588
#
# Iteration #22
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0626
# Epoch 2/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0618
# Epoch 3/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0621
# Epoch 4/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0619
# Epoch 5/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0615
# Epoch 6/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0616
# Epoch 7/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0616
# Epoch 8/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0611
#
# Iteration #23
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0604
# Epoch 2/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0607
# Epoch 3/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0604
# Epoch 4/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0607
# Epoch 5/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0597
# Epoch 6/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0595
# Epoch 7/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0596
# Epoch 8/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0597
#
# Iteration #24
# ________________________________________________________________________________
#
# Epoch 1/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0625
# Epoch 2/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0617
# Epoch 3/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0618
# Epoch 4/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0624
# Epoch 5/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0616
# Epoch 6/8
# 1/1 [==============================] - 0s 36ms/step - loss: 0.0618
# Epoch 7/8
# 1/1 [==============================] - 0s 35ms/step - loss: 0.0618
# Epoch 8/8
# 1/1 [==============================] - 0s 34ms/step - loss: 0.0611

# %% [markdown]
# ## Stats
#
# After training it's usually useful to see whether the loss has decreased or how close to the target data the generated data is. For this, we have some `matplotlib` plots right here.

# %%
# %matplotlib inline

plt.plot(loss)
plt.title("Loss")
plt.show()

# %%
from matplotlib.collections import LineCollection
from matplotlib.colors import LinearSegmentedColormap

def plot_error_colormapped_axis_position(target, predicted, axis):
    fig = plt.figure(figsize=(18, 2), dpi= 80, facecolor='w', edgecolor='k')
    
    fig.gca().plot(target[:,axis], color='black', alpha=0.3)
    cmap = LinearSegmentedColormap.from_list("", [(0, 0.8, 0), (0.8, 0, 0)])
    time = np.linspace(0, len(predicted), len(predicted))
    pos = predicted[:,axis]
    diff = np.absolute(target[:,axis] - predicted[:,axis])
    points = np.array([time, pos]).T.reshape(-1,1,2)
    segments = np.concatenate([points[:-2],points[1:-1], points[2:]], axis=1)
    
    norm = plt.Normalize(diff.min(), diff.max())
    
    lc = LineCollection(segments, cmap=cmap, norm=norm)
    lc.set_array(diff)
    fig.gca().add_collection(lc)
    fig.gca().autoscale()
    fig.show()

def plot_info(target, predicted):
    # %matplotlib inline
    
    plot_error_colormapped_axis_position(target, predicted, 0)
    plt.title("X")
    plt.show()
    
    plot_error_colormapped_axis_position(target, predicted, 1)
    plt.title("Y")
    plt.show()

# %%
predicted_pos = model.predict(X)
    
for i in range(10):
    print("Batch", i)
    plot_info(y[i], predicted_pos[i])
    print()
    print()
    print()
# Out:
# 1/1 [==============================] - 1s 547ms/step
# Batch 0
# /tmp/ipykernel_182/1172362003.py:21: UserWarning: FigureCanvasAgg is non-interactive, and thus cannot be shown
#   fig.show()
# Batch 1
# Batch 2
# Batch 3
# Batch 4
# Batch 5
# Batch 6
# Batch 7
# Batch 8
# Batch 9

# %% [markdown]
# You might have noticed that even when the loss is as low as 0.06 the predictions do not match the target data quite so well. That is not a huge problem though, since we do not really want the IA to match exactly our moves on every replay.
#
# The movements between a circle and the next one on osu! are mostly unpredictable, and the best we can do is approximate them. The really important part is that the IA can aim for the circles and move the cursor over them in time.
#
# Implementing a GAN would solve most of these problems, as it would not try to generate replays exactly like the target data, but replays that "look similar" to them. That will be explored in the future.
#
# Finally, let's validate our model and preview a replay it generates for a map it has never seen before:

# %%
BEATMAPS_FOLDER = os.path.join(OSU_FOLDER, 'Songs')
print(glob.glob(BEATMAPS_FOLDER + "/**/*.osu"))
BEATMAP = glob.glob(BEATMAPS_FOLDER + "/**/*.osu")[0]
print(BEATMAP)

# Load beatmap data
beatmap = osu.rulesets.beatmap.load(BEATMAP)
data = osulearn.dataset.input_data(beatmap)
data = np.reshape(data.values, (-1, osulearn.dataset.BATCH_LENGTH, len(osulearn.dataset.INPUT_FEATURES)))

# Generate AI replay
predicted = model.predict(data)

# Plot both
plot_info(np.concatenate(data), np.concatenate(predicted))

# Save
beatmap_name = beatmap['Title'] + ' (' + beatmap['Creator'] + ') [' + beatmap['Version'] + ']'
replay_data = np.concatenate(predicted)

if not os.path.exists('.generated'):
    os.makedirs('.generated')
    
np.save('.generated\\' + beatmap_name + '.npy', replay_data)

print("Done.")
# Out:
# ['/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1271261 Yunomi - Koi no Uta (feat Yuzaki Tsukasa (CV Kito Akari)) (TV Size)/Yunomi - Koi no Uta (feat. Yuzaki Tsukasa (CV Kito Akari)) (TV Size) (hypercyte) [Easy].osu', '/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1271261 Yunomi - Koi no Uta (feat Yuzaki Tsukasa (CV Kito Akari)) (TV Size)/Yunomi - Koi no Uta (feat. Yuzaki Tsukasa (CV Kito Akari)) (TV Size) (hypercyte) [Expert].osu', '/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1271261 Yunomi - Koi no Uta (feat Yuzaki Tsukasa (CV Kito Akari)) (TV Size)/Yunomi - Koi no Uta (feat. Yuzaki Tsukasa (CV Kito Akari)) (TV Size) (hypercyte) [Hard].osu', "/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1271261 Yunomi - Koi no Uta (feat Yuzaki Tsukasa (CV Kito Akari)) (TV Size)/Yunomi - Koi no Uta (feat. Yuzaki Tsukasa (CV Kito Akari)) (TV Size) (hypercyte) [Nao's Insane].osu", '/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1271261 Yunomi - Koi no Uta (feat Yuzaki Tsukasa (CV Kito Akari)) (TV Size)/Yunomi - Koi no Uta (feat. Yuzaki Tsukasa (CV Kito Akari)) (TV Size) (hypercyte) [Normal].osu', '/mnt/c/Users/Omen/AppData/Local/osu!/Songs/138330 ZAQ - VOICE (TV Size)/ZAQ - VOICE (TV Size) (wcx19911123) [Easy].osu', "/mnt/c/Users/Omen/AppData/Local/osu!/Songs/138330 ZAQ - VOICE (TV Size)/ZAQ - VOICE (TV Size) (wcx19911123) [Fycho's Hard].osu", '/mnt/c/Users/Omen/AppData/Local/osu!/Songs/138330 ZAQ - VOICE (TV Size)/ZAQ - VOICE (TV Size) (wcx19911123) [Insane].osu', "/mnt/c/Users/Omen/AppData/Local/osu!/Songs/138330 ZAQ - VOICE (TV Size)/ZAQ - VOICE (TV Size) (wcx19911123) [Kodora's Normal].osu", '/mnt/c/Users/Omen/AppData/Local/osu!/Songs/138330 ZAQ - VOICE (TV Size)/ZAQ - VOICE (TV Size) (wcx19911123) [VOICE (Extra)].osu', "/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1428768 hitorie - 3-pun 29-byou (TV Size)/hitorie - 3-pun 29-byou (TV Size) (Saggin) [GodKei's insane].osu", '/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1428768 hitorie - 3-pun 29-byou (TV Size)/hitorie - 3-pun 29-byou (TV Size) (Saggin) [Nonexistence].osu', '/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1428768 hitorie - 3-pun 29-byou (TV Size)/hitorie - 3-pun 29-byou (TV Size) (Saggin) [Normal].osu', "/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1428768 hitorie - 3-pun 29-byou (TV Size)/hitorie - 3-pun 29-byou (TV Size) (Saggin) [sanairrt's Hard].osu", '/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1435750 SawanoHiroyuki[nZk] mizuki - Avid (TV Size)/SawanoHiroyuki[nZk]mizuki - Avid (TV Size) (Maot) [colorata].osu', "/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1435750 SawanoHiroyuki[nZk] mizuki - Avid (TV Size)/SawanoHiroyuki[nZk]mizuki - Avid (TV Size) (Maot) [Moete's Hard].osu", '/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1435750 SawanoHiroyuki[nZk] mizuki - Avid (TV Size)/SawanoHiroyuki[nZk]mizuki - Avid (TV Size) (Maot) [Normal].osu', '/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1513912 fhana - Ai no Supreme! (TV Size)/fhana - Ai no Supreme! (TV Size) (toybot) [Easy].osu', '/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1513912 fhana - Ai no Supreme! (TV Size)/fhana - Ai no Supreme! (TV Size) (toybot) [My Angel Kanna].osu', '/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1513912 fhana - Ai no Supreme! (TV Size)/fhana - Ai no Supreme! (TV Size) (toybot) [Normal].osu', "/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1513912 fhana - Ai no Supreme! (TV Size)/fhana - Ai no Supreme! (TV Size) (toybot) [Seolv's Hard].osu", "/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1513912 fhana - Ai no Supreme! (TV Size)/fhana - Ai no Supreme! (TV Size) (toybot) [Sing's Insane].osu", '/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1592522 amazarashi - Kyoukaisen (TV Size)/amazarashi - Kyoukaisen (TV Size) (Soue) [Easy].osu', '/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1592522 amazarashi - Kyoukaisen (TV Size)/amazarashi - Kyoukaisen (TV Size) (Soue) [Expert].osu', "/mnt/c/Users/Omen/AppData/Local/osu!/Songs/1592522 amazarashi - Kyoukaisen (TV Size)/amazarashi - Kyoukaisen (TV Size) (Soue) [GodKei's Insane].osu", '/mnt/c/Users/Omen/AppDa ...
# /mnt/c/Users/Omen/AppData/Local/osu!/Songs/1271261 Yunomi - Koi no Uta (feat Yuzaki Tsukasa (CV Kito Akari)) (TV Size)/Yunomi - Koi no Uta (feat. Yuzaki Tsukasa (CV Kito Akari)) (TV Size) (hypercyte) [Easy].osu
# <class 'osu.rulesets.beatmap.Beatmap'>
# <osu.rulesets.beatmap.Beatmap object at 0x7fc569f41a90>

# %% [markdown]
# To preview the generated replay, run this on OsuLearn root directory:
# ```
# python -m osu.preview
# ```
#
# This script needs [`pygame`](https://www.pygame.org/news) and [`mutagen`](https://mutagen.readthedocs.io/en/latest/) to run.

# %% [markdown]
# ## Known Issues
#
# Ok, so we've seen the AI can do quite well even on maps it has never been trained to play before, but of course there's some things we can notice it can't do at all:
#
# - Spinners: It simply ignores them, haha!
# - Break time "random" movements: during break times the best it can do is just hold the cursor on the center of the screen.
#
# What I would guess is happening is that those two actions usually do not have an easily distinguishable pattern to them (spinners are usually "spinned", I know, but it's not as precise as aiming or following sliders, since spin direction, speed, radius, etc. varies a lot in a way that is not really predictable). Since we're using a kind of regression technique, it makes sense the model couldn't figure those out.
#
# The solution?
#
# Use a GAN!!! (╯°□°)╯︵ ┻━┻
